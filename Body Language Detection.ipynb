# %% [markdown]
# ## Installing Libraries

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\dell\anaconda3\lib\site-packages (0.8.4.2)
# Requirement already satisfied: opencv-python in c:\users\dell\anaconda3\lib\site-packages (4.5.2.52)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\lib\site-packages (0.22.1)
# Requirement already satisfied: protobuf>=3.11.4 in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (3.17.0)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (1.18.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (19.3.0)
# Requirement already satisfied: six in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (1.14.0)
# Requirement already satisfied: wheel in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (0.34.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (4.5.2.52)
# Requirement already satisfied: absl-py in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (0.12.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn) (0.14.1)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn) (1.4.1)

# %% [markdown]
# ## Importing Libraries

# %%
import mediapipe as mp
import cv2

# %%
mp_holistic = mp.solutions.holistic  # Pre trained models for face , hand and pose detection
mp_drawing = mp.solutions.drawing_utils   # Draw the connections

# %%
'''
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    cv2.imshow('Raw Webcam Feed', frame)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
'''

# %%
# Camera Check....123....123.....123

cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )
        
        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Making Landmarks and importing them in a csv file

# %%
# New Libraries
import pandas as pd
import numpy as np
import csv

# %%
new_coordinates = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
new_coordinates
# Out:
# 501

# %%
landmark = ['Class']
for i in range(1,new_coordinates+1):
    landmark += ['x{}'.format(i) , 'y{}'.format(i) , 'z{}'.format(i) , 'visibility{}'.format(i)]

# %%
landmark
# Out:
# ['Class',
#  'x1',
#  'y1',
#  'z1',
#  'visibility1',
#  'x2',
#  'y2',
#  'z2',
#  'visibility2',
#  'x3',
#  'y3',
#  'z3',
#  'visibility3',
#  'x4',
#  'y4',
#  'z4',
#  'visibility4',
#  'x5',
#  'y5',
#  'z5',
#  'visibility5',
#  'x6',
#  'y6',
#  'z6',
#  'visibility6',
#  'x7',
#  'y7',
#  'z7',
#  'visibility7',
#  'x8',
#  'y8',
#  'z8',
#  'visibility8',
#  'x9',
#  'y9',
#  'z9',
#  'visibility9',
#  'x10',
#  'y10',
#  'z10',
#  'visibility10',
#  'x11',
#  'y11',
#  'z11',
#  'visibility11',
#  'x12',
#  'y12',
#  'z12',
#  'visibility12',
#  'x13',
#  'y13',
#  'z13',
#  'visibility13',
#  'x14',
#  'y14',
#  'z14',
#  'visibility14',
#  'x15',
#  'y15',
#  'z15',
#  'visibility15',
#  'x16',
#  'y16',
#  'z16',
#  'visibility16',
#  'x17',
#  'y17',
#  'z17',
#  'visibility17',
#  'x18',
#  'y18',
#  'z18',
#  'visibility18',
#  'x19',
#  'y19',
#  'z19',
#  'visibility19',
#  'x20',
#  'y20',
#  'z20',
#  'visibility20',
#  'x21',
#  'y21',
#  'z21',
#  'visibility21',
#  'x22',
#  'y22',
#  'z22',
#  'visibility22',
#  'x23',
#  'y23',
#  'z23',
#  'visibility23',
#  'x24',
#  'y24',
#  'z24',
#  'visibility24',
#  'x25',
#  'y25',
#  'z25',
#  'visibility25',
#  'x26',
#  'y26',
#  'z26',
#  'visibility26',
#  'x27',
#  'y27',
#  'z27',
#  'visibility27',
#  'x28',
#  'y28',
#  'z28',
#  'visibility28',
#  'x29',
#  'y29',
#  'z29',
#  'visibility29',
#  'x30',
#  'y30',
#  'z30',
#  'visibility30',
#  'x31',
#  'y31',
#  'z31',
#  'visibility31',
#  'x32',
#  'y32',
#  'z32',
#  'visibility32',
#  'x33',
#  'y33',
#  'z33',
#  'visibility33',
#  'x34',
#  'y34',
#  'z34',
#  'visibility34',
#  'x35',
#  'y35',
#  'z35',
#  'visibility35',
#  'x36',
#  'y36',
#  'z36',
#  'visibility36',
#  'x37',
#  'y37',
#  'z37',
#  'visibility37',
#  'x38',
#  'y38',
#  'z38',
#  'visibility38',
#  'x39',
#  'y39',
#  'z39',
#  'visibility39',
#  'x40',
#  'y40',
#  'z40',
#  'visibility40',
#  'x41',
#  'y41',
#  'z41',
#  'visibility41',
#  'x42',
#  'y42',
#  'z42',
#  'visibility42',
#  'x43',
#  'y43',
#  'z43',
#  'visibility43',
#  'x44',
#  'y44',
#  'z44',
#  'visibility44',
#  'x45',
#  'y45',
#  'z45',
#  'visibility45',
#  'x46',
#  'y46',
#  'z46',
#  'visibility46',
#  'x47',
#  'y47',
#  'z47',
#  'visibility47',
#  'x48',
#  'y48',
#  'z48',
#  'visibility48',
#  'x49',
#  'y49',
#  'z49',
#  'visibility49',
#  'x50',
#  'y50',
#  'z50',
#  'visibility50',
#  'x51',
#  'y51',
#  'z51',
#  'visibility51',
#  'x52',
#  'y52',
#  'z52',
#  'visibility52',
#  'x53',
#  'y53',
#  'z53',
#  'visibility53',
#  'x54',
#  'y54',
#  'z54',
#  'visibility54',
#  'x55',
#  'y55',
#  'z55',
#  'visibility55',
#  'x56',
#  'y56',
#  'z56',
#  'visibility56',
#  'x57',
#  'y57',
#  'z57',
#  'visibility57',
#  'x58',
#  'y58',
#  'z58',
#  'visibility58',
#  'x59',
#  'y59',
#  'z59',
#  'visibility59',
#  'x60',
#  'y60',
#  'z60',
#  'visibility60',
#  'x61',
#  'y61',
#  'z61',
#  'visibility61',
#  'x62',
#  'y62',
#  'z62',
#  'visibility62',
#  'x63',
#  'y63',
#  'z63',
#  'visibility63',
#  'x64',
#  'y64',
#  'z64',
#  'visibility64',
#  'x65',
#  'y65',
#  'z65',
#  'visibility65',
#  'x66',
#  'y66',
#  'z66',
#  'visibility66',
#  'x67',
#  'y67',
#  'z67',
#  'visibility67',
#  'x68',
#  'y68',
#  'z68',
#  'visibility68',
#  'x69',
#  'y69',
#  'z69',
#  'visibility69',
#  'x70',
#  'y70',
#  'z70',
#  'visibility70',
#  'x71',
#  'y71',
#  'z71',
#  'visibility71',
#  'x72',
#  'y72',
#  'z72',
#  'visibility72',
#  'x73',
#  'y73',
#  'z73',
#  'visibility73',
#  'x74',
#  'y74',
#  'z74',
#  'visibility74',
#  'x75',
#  'y75',
#  'z75',
#  'visibility75',
#  'x76',
#  'y76',
#  'z76',
#  'visibility76',
#  'x77',
#  'y77',
#  'z77',
#  'visibility77',
#  'x78',
#  'y78',
#  'z78',
#  'visibility78',
#  'x79',
#  'y79',
#  'z79',
#  'visibility79',
#  'x80',
#  'y80',
#  'z80',
#  'visibility80',
#  'x81',
#  'y81',
#  'z81',
#  'visibility81',
#  'x82',
#  'y82',
#  'z82',
#  'visibility82',
#  'x83',
#  'y83',
#  'z83',
#  'visibility83',
#  'x84',
#  'y84',
#  'z84',
#  'visibility84',
#  'x85',
#  'y85',
#  'z85',
#  'visibility85',
#  'x86',
#  'y86',
#  'z86',
#  'visibility86',
#  'x87',
#  'y87',
#  'z87',
#  'visibility87',
#  'x88',
#  'y88',
#  'z88',
#  'visibility88',
#  'x89',
#  'y89',
#  'z89',
#  'visibility89',
#  'x90',
#  'y90',
#  'z90',
#  'visibility90',
#  'x91',
#  'y91',
#  'z91',
#  'visibility91',
#  'x92',
#  'y92',
#  'z92',
#  'visibility92',
#  'x93',
#  'y93',
#  'z93',
#  'visibility93',
#  'x94',
#  'y94',
#  'z94',
#  'visibility94',
#  'x95',
#  'y95',
#  'z95',
#  'visibility95',
#  'x96',
#  'y96',
#  'z96',
#  'visibility96',
#  'x97',
#  'y97',
#  'z97',
#  'visibility97',
#  'x98',
#  'y98',
#  'z98',
#  'visibility98',
#  'x99',
#  'y99',
#  'z99',
#  'visibility99',
#  'x100',
#  'y100',
#  'z100',
#  'visibility100',
#  'x101',
#  'y101',
#  'z101',
#  'visibility101',
#  'x102',
#  'y102',
#  'z102',
#  'visibility102',
#  'x103',
#  'y103',
#  'z103',
#  'visibility103',
#  'x104',
#  'y104',
#  'z104',
#  'visibility104',
#  'x105',
#  'y105',
#  'z105',
#  'visibility105',
#  'x106',
#  'y106',
#  'z106',
#  'visibility106',
#  'x107',
#  'y107',
#  'z107',
#  'visibility107',
#  'x108',
#  'y108',
#  'z108',
#  'visibility108',
#  'x109',
#  'y109',
#  'z109',
#  'visibility109',
#  'x110',
#  'y110',
#  'z110',
#  'visibility110',
#  'x111',
#  'y111',
#  'z111',
#  'visibility111',
#  'x112',
#  'y112',
#  'z112',
#  'visibility112',
#  'x113',
#  'y113',
#  'z113',
#  'visibility113',
#  'x114',
#  'y114',
#  'z114',
#  'visibility114',
#  'x115',
#  'y115',
#  'z115',
#  'visibility115',
#  'x116',
#  'y116',
#  'z116',
#  'visibility116',
#  'x117',
#  'y117',
#  'z117',
#  'visibility117',
#  'x118',
#  'y118',
#  'z118',
#  'visibility118',
#  'x119',
#  'y119',
#  'z119',
#  'visibility119',
#  'x120',
#  'y120',
#  'z120',
#  'visibility120',
#  'x121',
#  'y121',
#  'z121',
#  'visibility121',
#  'x122',
#  'y122',
#  'z122',
#  'visibility122',
#  'x123',
#  'y123',
#  'z123',
#  'visibility123',
#  'x124',
#  'y124',
#  'z124',
#  'visibility124',
#  'x125',
#  'y125',
#  'z125',
#  'visibility125',
#  'x126',
#  'y126',
#  'z126',
#  'visibility126',
#  'x127',
#  'y127',
#  'z127',
#  'visibility127',
#  'x128',
#  'y128',
#  'z128',
#  'visibility128',
#  'x129',
#  'y129',
#  'z129',
#  'visibility129',
#  'x130',
#  'y130',
#  'z130',
#  'visibility130',
#  'x131',
#  'y131',
#  'z131',
#  'visibility131',
#  'x132',
#  'y132',
#  'z132',
#  'visibility132',
#  'x133',
#  'y133',
#  'z133',
#  'visibility133',
#  'x134',
#  'y134',
#  'z134',
#  'visibility134',
#  'x135',
#  'y135',
#  'z135',
#  'visibility135',
#  'x136',
#  'y136',
#  'z136',
#  'visibility136',
#  'x137',
#  'y137',
#  'z137',
#  'visibility137',
#  'x138',
#  'y138',
#  'z138',
#  'visibility138',
#  'x139',
#  'y139',
#  'z139',
#  'visibility139',
#  'x140',
#  'y140',
#  'z140',
#  'visibility140',
#  'x141',
#  'y141',
#  'z141',
#  'visibility141',
#  'x142',
#  'y142',
#  'z142',
#  'visibility142',
#  'x143',
#  'y143',
#  'z143',
#  'visibility143',
#  'x144',
#  'y144',
#  'z144',
#  'visibility144',
#  'x145',
#  'y145',
#  'z145',
#  'visibility145',
#  'x146',
#  'y146',
#  'z146',
#  'visibility146',
#  'x147',
#  'y147',
#  'z147',
#  'visibility147',
#  'x148',
#  'y148',
#  'z148',
#  'visibility148',
#  'x149',
#  'y149',
#  'z149',
#  'visibility149',
#  'x150',
#  'y150',
#  'z150',
#  'visibility150',
#  'x151',
#  'y151',
#  'z151',
#  'visibility151',
#  'x152',
#  'y152',
#  'z152',
#  'visibility152',
#  'x153',
#  'y153',
#  'z153',
#  'visibility153',
#  'x154',
#  'y154',
#  'z154',
#  'visibility154',
#  'x155',
#  'y155',
#  'z155',
#  'visibility155',
#  'x156',
#  'y156',
#  'z156',
#  'visibility156',
#  'x157',
#  'y157',
#  'z157',
#  'visibility157',
#  'x158',
#  'y158',
#  'z158',
#  'visibility158',
#  'x159',
#  'y159',
#  'z159',
#  'visibility159',
#  'x160',
#  'y160',
#  'z160',
#  'visibility160',
#  'x161',
#  'y161',
#  'z161',
#  'visibility161',
#  'x162',
#  'y162',
#  'z162',
#  'visibility162',
#  'x163',
#  'y163',
#  'z163',
#  'visibility163',
#  'x164',
#  'y164',
#  'z164',
#  'visibility164',
#  'x165',
#  'y165',
#  'z165',
#  'visibility165',
#  'x166',
#  'y166',
#  'z166',
#  'visibility166',
#  'x167',
#  'y167',
#  'z167',
#  'visibility167',
#  'x168',
#  'y168',
#  'z168',
#  'visibility168',
#  'x169',
#  'y169',
#  'z169',
#  'visibility169',
#  'x170',
#  'y170',
#  'z170',
#  'visibility170',
#  'x171',
#  'y171',
#  'z171',
#  'visibility171',
#  'x172',
#  'y172',
#  'z172',
#  'visibility172',
#  'x173',
#  'y173',
#  'z173',
#  'visibility173',
#  'x174',
#  'y174',
#  'z174',
#  'visibility174',
#  'x175',
#  'y175',
#  'z175',
#  'visibility175',
#  'x176',
#  'y176',
#  'z176',
#  'visibility176',
#  'x177',
#  'y177',
#  'z177',
#  'visibility177',
#  'x178',
#  'y178',
#  'z178',
#  'visibility178',
#  'x179',
#  'y179',
#  'z179',
#  'visibility179',
#  'x180',
#  'y180',
#  'z180',
#  'visibility180',
#  'x181',
#  'y181',
#  'z181',
#  'visibility181',
#  'x182',
#  'y182',
#  'z182',
#  'visibility182',
#  'x183',
#  'y183',
#  'z183',
#  'visibility183',
#  'x184',
#  'y184',
#  'z184',
#  'visibility184',
#  'x185',
#  'y185',
#  'z185',
#  'visibility185',
#  'x186',
#  'y186',
#  'z186',
#  'visibility186',
#  'x187',
#  'y187',
#  'z187',
#  'visibility187',
#  'x188',
#  'y188',
#  'z188',
#  'visibility188',
#  'x189',
#  'y189',
#  'z189',
#  'visibility189',
#  'x190',
#  'y190',
#  'z190',
#  'visibility190',
#  'x191',
#  'y191',
#  'z191',
#  'visibility191',
#  'x192',
#  'y192',
#  'z192',
#  'visibility192',
#  'x193',
#  'y193',
#  'z193',
#  'visibility193',
#  'x194',
#  'y194',
#  'z194',
#  'visibility194',
#  'x195',
#  'y195',
#  'z195',
#  'visibility195',
#  'x196',
#  'y196',
#  'z196',
#  'visibility196',
#  'x197',
#  'y197',
#  'z197',
#  'visibility197',
#  'x198',
#  'y198',
#  'z198',
#  'visibility198',
#  'x199',
#  'y199',
#  'z199',
#  'visibility199',
#  'x200',
#  'y200',
#  'z200',
#  'visibility200',
#  'x201',
#  'y201',
#  'z201',
#  'visibility201',
#  'x202',
#  'y202',
#  'z202',
#  'visibility202',
#  'x203',
#  'y203',
#  'z203',
#  'visibility203',
#  'x204',
#  'y204',
#  'z204',
#  'visibility204',
#  'x205',
#  'y205',
#  'z205',
#  'visibility205',
#  'x206',
#  'y206',
#  'z206',
#  'visibility206',
#  'x207',
#  'y207',
#  'z207',
#  'visibility207',
#  'x208',
#  'y208',
#  'z208',
#  'visibility208',
#  'x209',
#  'y209',
#  'z209',
#  'visibility209',
#  'x210',
#  'y210',
#  'z210',
#  'visibility210',
#  'x211',
#  'y211',
#  'z211',
#  'visibility211',
#  'x212',
#  'y212',
#  'z212',
#  'visibility212',
#  'x213',
#  'y213',
#  'z213',
#  'visibility213',
#  'x214',
#  'y214',
#  'z214',
#  'visibility214',
#  'x215',
#  'y215',
#  'z215',
#  'visibility215',
#  'x216',
#  'y216',
#  'z216',
#  'visibility216',
#  'x217',
#  'y217',
#  'z217',
#  'visibility217',
#  'x218',
#  'y218',
#  'z218',
#  'visibility218',
#  'x219',
#  'y219',
#  'z219',
#  'visibility219',
#  'x220',
#  'y220',
#  'z220',
#  'visibility220',
#  'x221',
#  'y221',
#  'z221',
#  'visibility221',
#  'x222',
#  'y222',
#  'z222',
#  'visibility222',
#  'x223',
#  'y223',
#  'z223',
#  'visibility223',
#  'x224',
#  'y224',
#  'z224',
#  'visibility224',
#  'x225',
#  'y225',
#  'z225',
#  'visibility225',
#  'x226',
#  'y226',
#  'z226',
#  'visibility226',
#  'x227',
#  'y227',
#  'z227',
#  'visibility227',
#  'x228',
#  'y228',
#  'z228',
#  'visibility228',
#  'x229',
#  'y229',
#  'z229',
#  'visibility229',
#  'x230',
#  'y230',
#  'z230',
#  'visibility230',
#  'x231',
#  'y231',
#  'z231',
#  'visibility231',
#  'x232',
#  'y232',
#  'z232',
#  'visibility232',
#  'x233',
#  'y233',
#  'z233',
#  'visibility233',
#  'x234',
#  'y234',
#  'z234',
#  'visibility234',
#  'x235',
#  'y235',
#  'z235',
#  'visibility235',
#  'x236',
#  'y236',
#  'z236',
#  'visibility236',
#  'x237',
#  'y237',
#  'z237',
#  'visibility237',
#  'x238',
#  'y238',
#  'z238',
#  'visibility238',
#  'x239',
#  'y239',
#  'z239',
#  'visibility239',
#  'x240',
#  'y240',
#  'z240',
#  'visibility240',
#  'x241',
#  'y241',
#  'z241',
#  'visibility241',
#  'x242',
#  'y242',
#  'z242',
#  'visibility242',
#  'x243',
#  'y243',
#  'z243',
#  'visibility243',
#  'x244',
#  'y244',
#  'z244',
#  'visibility244',
#  'x245',
#  'y245',
#  'z245',
#  'visibility245',
#  'x246',
#  'y246',
#  'z246',
#  'visibility246',
#  'x247',
#  'y247',
#  'z247',
#  'visibility247',
#  'x248',
#  'y248',
#  'z248',
#  'visibility248',
#  'x249',
#  'y249',
#  'z249',
#  'visibility249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmark)

# %%
class_name = 'Frustrated'

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )
        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Machine Learning Models

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
X = df.drop('Class', axis=1) # features
y = df['Class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
fit_models
# Out:
# {'lr': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('logisticregression',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=100,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=None,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'rc': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('ridgeclassifier',
#                   RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True,
#                                   fit_intercept=True, max_iter=None,
#                                   normalize=False, random_state=None,
#                                   solver='auto', tol=0.001))],
#           verbose=False),
#  'rf': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='auto',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=100, n_jobs=None,
#                                          oob_score=False, random_state=None,
#                                          verbose=0, warm_start=False))],
#           verbose=False),
#  'gb': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('gradientboostingclassifier',
#                   GradientBoostingClassifier(ccp_alpha=0.0,
#                                              criterion='friedman_mse', init=None,
#                                              learning_rate=0.1, loss='deviance',
#                                              max_depth=3, max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100,
#                                              n_iter_no_change=None,
#                                              presort='deprecated',
#                                              random_state=None, subsample=1.0,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False))],
#           verbose=False)}

# %% [markdown]
# ## Finding out the best model

# %%
import pickle
from sklearn.metrics import accuracy_score

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9748427672955975
# rc 0.9748427672955975
# rf 0.9748427672955975
# gb 0.9685534591194969

# %%
fit_models['lr'].predict(X_test)
# Out:
# array(['Happy', 'Sad', 'Frustrated', 'Happy', 'Happy', 'Frustrated',
#        'Sad', 'Happy', 'Sad', 'Sad', 'Frustrated', 'Frustrated',
#        'Frustrated', 'Sad', 'Sad', 'Frustrated', 'Frustrated', 'Happy',
#        'Sad', 'Sad', 'Frustrated', 'Frustrated', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Happy', 'Happy', 'Frustrated', 'Happy', 'Happy',
#        'Frustrated', 'Frustrated', 'Happy', 'Frustrated', 'Frustrated',
#        'Happy', 'Sad', 'Frustrated', 'Happy', 'Sad', 'Frustrated',
#        'Happy', 'Frustrated', 'Sad', 'Frustrated', 'Frustrated', 'Sad',
#        'Sad', 'Sad', 'Sad', 'Frustrated', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Sad', 'Sad', 'Frustrated', 'Frustrated', 'Happy', 'Frustrated',
#        'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Happy', 'Frustrated', 'Sad',
#        'Sad', 'Happy', 'Frustrated', 'Sad', 'Sad', 'Happy', 'Sad', 'Sad',
#        'Frustrated', 'Sad', 'Frustrated', 'Frustrated', 'Frustrated',
#        'Sad', 'Frustrated', 'Frustrated', 'Happy', 'Happy', 'Frustrated',
#        'Frustrated', 'Frustrated', 'Happy', 'Happy', 'Sad', 'Frustrated',
#        'Sad', 'Happy', 'Frustrated', 'Sad', 'Sad', 'Happy', 'Sad',
#        'Frustrated', 'Sad', 'Frustrated', 'Sad', 'Sad', 'Frustrated',
#        'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Frustrated', 'Frustrated',
#        'Frustrated', 'Frustrated', 'Frustrated', 'Sad', 'Happy', 'Happy',
#        'Frustrated', 'Sad', 'Frustrated', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Frustrated', 'Happy', 'Frustrated', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Frustrated', 'Sad', 'Happy', 'Sad', 'Frustrated', 'Sad', 'Sad',
#        'Frustrated', 'Sad', 'Frustrated', 'Frustrated', 'Sad',
#        'Frustrated', 'Sad', 'Frustrated', 'Sad', 'Sad', 'Happy',
#        'Frustrated', 'Sad', 'Happy', 'Frustrated', 'Happy', 'Sad'],
#       dtype=object)

# %%
y_test
# Out:
# 261         Happy
# 426           Sad
# 21     Frustrated
# 329         Happy
# 310         Happy
#           ...
# 362           Sad
# 338         Happy
# 24     Frustrated
# 324         Happy
# 437           Sad
# Name: Class, Length: 159, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['lr'], f)

# %% [markdown]
# ## Final detection using our ML Model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        '''
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 ) 
        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        '''
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (255, 255, 16), -1)
            
            # Display Class
            cv2.putText(image, 'Emotion'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'Probability'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image,str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Frustrated [9.99730102e-01 3.18357529e-05 2.38061985e-04]
# Frustrated [9.97986953e-01 4.20307376e-05 1.97101663e-03]
# Frustrated [0.714509   0.18071145 0.10477955]
# Happy [0.04956005 0.68454305 0.26589689]
# Happy [0.06707585 0.5841227  0.34880145]
# Happy [3.84665530e-04 9.99165162e-01 4.50172634e-04]
# Happy [7.58893126e-05 9.99633688e-01 2.90422895e-04]
# Happy [9.84361910e-05 9.99562765e-01 3.38798721e-04]
# Happy [1.48634244e-04 9.99593902e-01 2.57463570e-04]
# Happy [9.46773385e-05 9.88117491e-01 1.17878319e-02]
# Sad [5.46124470e-06 1.93284455e-04 9.99801254e-01]
# Sad [2.77710957e-06 2.97988885e-05 9.99967424e-01]
# Sad [2.21217817e-06 2.74572188e-05 9.99970331e-01]
# Sad [2.21346101e-05 1.08654287e-04 9.99869211e-01]
# Frustrated [9.86954801e-01 3.76269813e-09 1.30451955e-02]
# Frustrated [9.91363046e-01 4.60167666e-09 8.63694934e-03]
# Frustrated [9.70387451e-01 6.52443571e-08 2.96124835e-02]
# Frustrated [7.20313292e-01 3.01898685e-07 2.79686406e-01]
# Frustrated [9.25428670e-01 4.71288735e-07 7.45708583e-02]
# Happy [0.0170308  0.96820061 0.01476858]
# Happy [0.435252   0.56255817 0.00218983]
# Frustrated [0.92599137 0.00519349 0.06881514]
# Frustrated [0.57938157 0.00124286 0.41937557]
# Sad [0.38515627 0.00193555 0.61290819]
# Sad [0.00687732 0.0141621  0.97896058]
# Sad [4.92155700e-04 5.17161609e-02 9.47791683e-01]
# Happy [0.00743672 0.89003337 0.10252991]
# Happy [0.00858493 0.73828275 0.25313231]
# Happy [0.01281857 0.6648532  0.32232823]
# Happy [0.00809279 0.71099469 0.28091253]
# Happy [7.68069343e-04 8.71271422e-01 1.27960509e-01]
# Happy [0.00282146 0.80496273 0.1922158 ]
# Happy [0.00090958 0.89224107 0.10684935]
# Happy [0.00268515 0.85124963 0.14606522]
# Happy [0.00567908 0.87396752 0.12035341]
# Happy [0.00532658 0.82720487 0.16746855]
# Happy [0.00352788 0.90450005 0.09197207]
# Happy [0.00581349 0.79766252 0.19652399]
# Happy [0.011416   0.75411536 0.23446863]
# Happy [0.01509273 0.76892351 0.21598376]
# Happy [0.02355667 0.8622628  0.11418053]
# Happy [0.02333141 0.72438624 0.25228236]
# Happy [0.07202035 0.63193163 0.29604802]
# Happy [0.03083451 0.54345119 0.4257143 ]
# Happy [0.04262447 0.54970179 0.40767374]
# Sad [0.03611703 0.42081552 0.54306744]
# Sad [0.02514383 0.34517246 0.62968371]
# Sad [0.03240249 0.47613285 0.49146465]
# Happy [0.04590278 0.55350938 0.40058785]
# Sad [0.0755144  0.39157156 0.53291404]
# Sad [0.03060842 0.4571287  0.51226288]
# Sad [0.01206922 0.38582568 0.6021051 ]
# Sad [0.01134121 0.43777389 0.55088489]
# Sad [0.01230702 0.46365173 0.52404125]
# Happy [0.00754095 0.49938109 0.49307796]
# Happy [0.01073685 0.58989132 0.39937183]
# Happy [1.86477943e-04 9.97351318e-01 2.46220384e-03]
# Happy [1.08881305e-04 9.99742155e-01 1.48963744e-04]
# Happy [2.13714490e-04 9.99702007e-01 8.42785767e-05]
# Happy [3.35870679e-04 9.99561273e-01 1.02856097e-04]
# Happy [1.93679293e-04 9.99606037e-01 2.00283523e-04]
# Happy [8.68477120e-05 9.99689158e-01 2.23994020e-04]
# Happy [4.12843005e-04 9.98992368e-01 5.94788991e-04]
# Happy [5.54040788e-04 9.97935324e-01 1.51063543e-03]
# Happy [8.49425474e-04 9.96862504e-01 2.28807101e-03]
# Happy [1.64656596e-05 9.98919891e-01 1.06364308e-03]
# Happy [5.33653718e-05 9.91329929e-01 8.61670582e-03]
# Sad [6.98506135e-07 8.32488214e-06 9.99990977e-01]
# Sad [2.72649698e-07 2.00262275e-06 9.99997725e-01]
# Sad [2.91284497e-07 3.45220449e-06 9.99996257e-01]
# Sad [2.18268150e-07 4.05903245e-06 9.99995723e-01]
# Sad [1.70247380e-07 4.55606908e-06 9.99995274e-01]
# Sad [2.09088259e-07 9.31988028e-06 9.99990471e-01]
# Sad [4.40819199e-05 7.09372369e-02 9.29018681e-01]
# Happy [4.97262527e-04 9.78369144e-01 2.11335933e-02]
# Happy [2.32378699e-04 9.89327775e-01 1.04398464e-02]
# Happy [1.64518277e-04 9.93523148e-01 6.31233378e-03]
# Happy [3.03494773e-04 9.97507962e-01 2.18854351e-03]
# Happy [2.89878284e-04 9.98501890e-01 1.20823125e-03]
# Happy [2.85391185e-04 8.75540813e-01 1.24173796e-01]
# Sad [5.89783395e-05 2.27609894e-04 9.99713412e-01]
# Sad [8.73041221e-06 1.20771968e-04 9.99870498e-01]
# Sad [3.53935681e-06 1.12744559e-04 9.99883716e-01]
# Sad [6.08762655e-06 1.44802604e-04 9.99849110e-01]
# Sad [2.30704553e-06 1.01595677e-05 9.99987533e-01]
# Sad [1.22845313e-06 1.33182311e-08 9.99998758e-01]
# Sad [4.70558965e-01 1.74319298e-12 5.29441035e-01]
# Frustrated [7.23771873e-01 2.66761953e-12 2.76228127e-01]
# Sad [4.65626406e-01 5.29454134e-12 5.34373594e-01]
# Frustrated [9.77631549e-01 1.38109972e-11 2.23684508e-02]
# Sad [2.08507906e-01 9.56716740e-11 7.91492094e-01]
# Frustrated [5.10968929e-01 3.43624057e-11 4.89031071e-01]
# Frustrated [9.41221348e-01 1.66731128e-10 5.87786520e-02]
# Sad [2.86221126e-01 4.04750306e-10 7.13778874e-01]
# Frustrated [8.10098860e-01 3.47975268e-11 1.89901140e-01]
# Sad [1.24114440e-01 5.63770451e-11 8.75885560e-01]
# Sad [1.83791784e-01 1.51269150e-10 8.16208216e-01]
# Sad [7.44353930e-04 4.39992449e-09 9.99255642e-01]
# Frustrated [8.14831750e-01 1.02656862e-10 1.85168250e-01]
# Frustrated [9.74684272e-01 7.11697583e-11 2.53157283e-02]
# Frustrated [7.90935675e-01 4.31648904e-10 2.09064325e-01]
# Frustrated [9.51639884e-01 2.96818936e-10 4.83601156e-02]
# Frustrated [8.93479342e-01 6.89168431e-10 1.06520658e-01]
# Frustrated [8.49916526e-01 1.12142289e-09 1.50083473e-01]
# Frustrated [9.76729224e-01 1.51865041e-12 2.32707759e-02]
# Frustrated [8.47394719e-01 3.19143125e-12 1.52605281e-01]
# Frustrated [9.21998716e-01 9.96980283e-12 7.80012839e-02]
# Frustrated [8.59816767e-01 1.82241906e-12 1.40183233e-01]
# Frustrated [9.17892727e-01 1.90524201e-12 8.21072734e-02]
# Sad [2.14296994e-01 2.03726232e-10 7.85703005e-01]
# Frustrated [7.30872981e-01 1.47839354e-10 2.69127019e-01]
# Sad [5.65690567e-08 9.88477455e-05 9.99901096e-01]
# Happy [0.00330831 0.94457142 0.05212027]
# Happy [0.13686425 0.82421768 0.03891808]
# Happy [0.12373791 0.80652284 0.06973925]
# Happy [0.23867932 0.68893613 0.07238454]
# Frustrated [0.6903299  0.2739276  0.03574251]
# Frustrated [0.64883453 0.16107961 0.19008585]
# Sad [7.04059300e-04 7.65258887e-06 9.99288288e-01]
# Sad [1.19285246e-05 1.00764269e-05 9.99977995e-01]
# Sad [7.87848587e-06 4.96528986e-06 9.99987156e-01]
# Sad [1.35230343e-05 8.03180397e-06 9.99978445e-01]
# Sad [2.36341306e-05 8.61390522e-06 9.99967752e-01]
# Sad [1.86025432e-06 8.99205681e-07 9.99997241e-01]
# Sad [1.74699030e-05 2.98829636e-06 9.99979542e-01]
# Sad [1.39837211e-06 8.03333402e-07 9.99997798e-01]
# Sad [5.79996493e-07 1.18242602e-07 9.99999302e-01]
# Sad [2.46243716e-07 2.49968110e-07 9.99999504e-01]
# Sad [2.00223515e-06 7.12208233e-07 9.99997286e-01]
# Sad [8.03351094e-05 8.73981184e-06 9.99910925e-01]
# Sad [0.04356271 0.1216169  0.83482039]
# Frustrated [9.99529743e-01 7.95083626e-05 3.90749021e-04]
# Frustrated [9.99862273e-01 3.59866863e-05 1.01740735e-04]
# Frustrated [9.98795946e-01 7.59864108e-04 4.44189937e-04]
# Frustrated [9.99921492e-01 9.59419933e-06 6.89135986e-05]
# Frustrated [9.98435134e-01 3.29634125e-05 1.53190306e-03]
